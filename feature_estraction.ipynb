# %% [markdown]
# <a href="https://colab.research.google.com/github/Umberto28/Deep_Learning_Project/blob/main/feature_estraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Estrazione delle Features**
# Qui utilizziamo diverse architetture di Reti Neurali per estrarre le features dalle immagini del dataset

# %%
# Import general
import os
import pandas as pd
import numpy as np
from sklearn.calibration import LabelEncoder
import tensorflow as tf
import keras
from keras.models import Model
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications.efficientnet import preprocess_input

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **1. Creazione dataset**

# %%
ds1D='/content/drive/MyDrive/DeepLearning/datasetLabel/NoAugmentation/Dysgraphic1'
ds1N='/content/drive/MyDrive/DeepLearning/datasetLabel/NoAugmentation/No_Dysgraphic1'
ds2D='/content/drive/MyDrive/DeepLearning/datasetLabel/NoAugmentation/Dysgraphic2'
ds2N='/content/drive/MyDrive/DeepLearning/datasetLabel/NoAugmentation/No_Dysgraphic2'

ds1DA='/content/drive/MyDrive/DeepLearning/datasetLabel/Augmentation/Dysgraphic1'
ds1NA='/content/drive/MyDrive/DeepLearning/datasetLabel/Augmentation/No_Dysgraphic1'
ds2DA='/content/drive/MyDrive/DeepLearning/datasetLabel/Augmentation/Dysgraphic2'
ds2NA='/content/drive/MyDrive/DeepLearning/datasetLabel/Augmentation/No_Dysgraphic2'

# %%
#dataset primario senza augmentation
ds1D_paths = [os.path.join(ds1D, f) for f in os.listdir(ds1D)]
ds1N_paths = [os.path.join(ds1N, f) for f in os.listdir(ds1N)]

df1D=pd.DataFrame()
df1D['path']=ds1D_paths
df1D['diag']=1

df1N=pd.DataFrame()
df1N['path']=ds1N_paths
df1N['diag']=0
df1=pd.concat([df1D, df1N],  ignore_index=True)
df1
# Out:
#                                                   path  diag
# 0    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 1    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 2    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 3    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 4    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# ..                                                 ...   ...
# 115  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 116  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 117  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 118  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 119  /content/drive/MyDrive/DeepLearning/datasetLab...     0
#
# [120 rows x 2 columns]

# %%
# dataset secondatio senza augmetation
ds2D_paths = [os.path.join(ds2D, f) for f in os.listdir(ds2D)]
ds2N_paths = [os.path.join(ds2N, f) for f in os.listdir(ds2N)]

df2D=pd.DataFrame()
df2D['path']=ds2D_paths
df2D['diag']=1

df2N=pd.DataFrame()
df2N['path']=ds2N_paths
df2N['diag']=0
df2=pd.concat([df2D, df2N, df1],  ignore_index=True)
df2
# Out:
#                                                   path  diag
# 0    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 1    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 2    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 3    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 4    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# ..                                                 ...   ...
# 364  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 365  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 366  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 367  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 368  /content/drive/MyDrive/DeepLearning/datasetLab...     0
#
# [369 rows x 2 columns]

# %%
# dataset secondatio con cropping
ds2DAugC_paths = [os.path.join(ds2DA, f) for f in os.listdir(ds2DA) if f.startswith('crop')]
ds2NAugC_paths = [os.path.join(ds2NA, f) for f in os.listdir(ds2NA) if f.startswith('crop')]

df2DAugC=pd.DataFrame()
df2DAugC['path']=ds2DAugC_paths
df2DAugC['diag']=1

df2NAugC=pd.DataFrame()
df2NAugC['path']=ds2NAugC_paths
df2NAugC['diag']=0
df2AugC=pd.concat([df2DAugC, df2NAugC, df1DAugC, df1NAugC, df2],  ignore_index=True)
df2AugC
# Out:
#                                                    path  diag
# 0     /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 1     /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 2     /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 3     /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 4     /content/drive/MyDrive/DeepLearning/datasetLab...     1
# ...                                                 ...   ...
# 1471  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 1472  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 1473  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 1474  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 1475  /content/drive/MyDrive/DeepLearning/datasetLab...     0
#
# [1476 rows x 2 columns]

# %%
# dataset secondatio con flipping
ds2DAugF_paths = [os.path.join(ds2DA, f) for f in os.listdir(ds2DA) if f.startswith('flipped')]
ds2NAugF_paths = [os.path.join(ds2NA, f) for f in os.listdir(ds2NA) if f.startswith('flipped')]

df2DAugF=pd.DataFrame()
df2DAugF['path']=ds2DAugF_paths
df2DAugF['diag']=1

df2NAugF=pd.DataFrame()
df2NAugF['path']=ds2NAugF_paths
df2NAugF['diag']=0
df2AugF=pd.concat([df2DAugF, df2NAugF, df1DAugF, df1NAugF, df2],  ignore_index=True)
df2AugF
# Out:
#                                                   path  diag
# 0    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 1    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 2    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 3    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 4    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# ..                                                 ...   ...
# 733  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 734  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 735  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 736  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 737  /content/drive/MyDrive/DeepLearning/datasetLab...     0
#
# [738 rows x 2 columns]

# %%
# dataset secondatio con rumore
ds2DAugN_paths = [os.path.join(ds2DA, f) for f in os.listdir(ds2DA) if f.startswith('noisy')]
ds2NAugN_paths = [os.path.join(ds2NA, f) for f in os.listdir(ds2NA) if f.startswith('noisy')]

df2DAugN=pd.DataFrame()
df2DAugN['path']=ds2DAugN_paths
df2DAugN['diag']=1

df2NAugN=pd.DataFrame()
df2NAugN['path']=ds2NAugN_paths
df2NAugN['diag']=0
df2AugN=pd.concat([df2DAugN, df2NAugN, df1DAugN, df1NAugN, df2],  ignore_index=True)
df2AugN
# Out:
#                                                   path  diag
# 0    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 1    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 2    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 3    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 4    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# ..                                                 ...   ...
# 716  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 717  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 718  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 719  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 720  /content/drive/MyDrive/DeepLearning/datasetLab...     0
#
# [721 rows x 2 columns]

# %%
# dataset secondatio con rotazione
ds2DAugR_paths = [os.path.join(ds2DA, f) for f in os.listdir(ds2DA) if f.startswith('rotated')]
ds2NAugR_paths = [os.path.join(ds2NA, f) for f in os.listdir(ds2NA) if f.startswith('rotated')]

df2DAugR=pd.DataFrame()
df2DAugR['path']=ds2DAugR_paths
df2DAugR['diag']=1

df2NAugR=pd.DataFrame()
df2NAugR['path']=ds2NAugR_paths
df2NAugR['diag']=0
df2AugR=pd.concat([df2DAugR, df2NAugR, df1DAugR, df1NAugR, df2],  ignore_index=True)
df2AugR
# Out:
#                                                   path  diag
# 0    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 1    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 2    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 3    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 4    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# ..                                                 ...   ...
# 733  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 734  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 735  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 736  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 737  /content/drive/MyDrive/DeepLearning/datasetLab...     0
#
# [738 rows x 2 columns]

# %%
# dataset secondatio con trasllazione
ds2DAugT_paths = [os.path.join(ds2DA, f) for f in os.listdir(ds2DA) if f.startswith('tranlated')]
ds2NAugT_paths = [os.path.join(ds2NA, f) for f in os.listdir(ds2NA) if f.startswith('tranlated')]

df2DAugT=pd.DataFrame()
df2DAugT['path']=ds2DAugT_paths
df2DAugT['diag']=1

df2NAugT=pd.DataFrame()
df2NAugT['path']=ds2NAugT_paths
df2NAugT['diag']=0
df2AugT=pd.concat([df2DAugT, df2NAugT, df1DAugT, df1NAugT, df2],  ignore_index=True)
df2AugT
# Out:
#                                                   path  diag
# 0    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 1    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 2    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 3    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# 4    /content/drive/MyDrive/DeepLearning/datasetLab...     1
# ..                                                 ...   ...
# 484  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 485  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 486  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 487  /content/drive/MyDrive/DeepLearning/datasetLab...     0
# 488  /content/drive/MyDrive/DeepLearning/datasetLab...     0
#
# [489 rows x 2 columns]

# %%
# Assegnamo ad ogni paziente l'immagine corrispondende
def featureExtract(model, paths, t):
  features={}   #prepariamo il dataframe di output
  features=pd.DataFrame(features)
  for path in paths:
    #per ogni utente carichiamo e formattiamo le immagini
    if t=='x':
      img = keras.utils.load_img(path, target_size=(299, 299))
    if t=='e':
      img = keras.utils.load_img(path, target_size=(380, 380))
    x = keras.utils.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    feature=model.predict(x)[0] #estraiamo le feature
    row=pd.DataFrame([feature])
    features=pd.concat([features,row], ignore_index=True)   #concateniamo tutto
  return features

# %%
#eliminiamo l'ultimo strato di classificazione per estrarre solamente le feature
modelX=tf.keras.applications.xception.Xception(weights='imagenet',include_top=True)
modelX=Model(inputs=modelX.inputs, outputs=modelX.layers[-2].output)
# Out:
# ...
# 91884032/91884032 [==============================] - 1s 0us/step

# %%
#eliminiamo l'ultimo strato di classificazione per estrarre solamente le feature
modelE=tf.keras.applications.EfficientNetB4(weights='imagenet',include_top=True)
modelE=Model(inputs=modelE.inputs, outputs=modelE.layers[-2].output)
# Out:
# ...
# 78864416/78864416 [==============================] - 2s 0us/step

# %%
#Estrazione feature seccondo dataset senza augmentation

features=featureExtract(modelE, df2['path'], 'e')

features['diag']=df2['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/EfficientNetFeaturesAugg.csv')

features=featureExtract(modelX, df2['path'], 'x')

features['diag']=df2['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/XceptionFeaturesAugg.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 368ms/step

# %%
#Estrazione feature secondo dataset con cropping

features=featureExtract(modelE, df2AugC['path'], 'e')

features['diag']=df2AugC['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/EfficientNetFeaturesAuggCrop.csv')

features=featureExtract(modelX, df2AugC['path'], 'x')

features['diag']=df2AugC['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/XceptionFeaturesAuggCrop.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 467ms/step
# ...
# ...
# 1/1 [==============================] - 0s 383ms/step

# %%
#Estrazione feature secondo dataset con flipping

features=featureExtract(modelE, df2AugF['path'], 'e')

features['diag']=df2AugF['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/EfficientNetFeaturesAuggFlipped.csv')

features=featureExtract(modelX, df2AugF['path'], 'x')

features['diag']=df2AugF['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/XceptionFeaturesAuggFlipped.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 355ms/step
# ...
# ...
# 1/1 [==============================] - 0s 355ms/step

# %%
#Estrazione feature secondo dataset con rumore

features=featureExtract(modelE, df2AugN['path'], 'e')

features['diag']=df2AugN['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/EfficientNetFeaturesAuggNoisy.csv')

features=featureExtract(modelX, df2AugN['path'], 'x')

features['diag']=df2AugN['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/XceptionFeaturesAuggNoisy.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 367ms/step
# ...
# ...
# 1/1 [==============================] - 0s 366ms/step

# %%
#Estrazione feature secondo dataset con rotazione

features=featureExtract(modelE, df2AugR['path'], 'e')

features['diag']=df2AugR['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/EfficientNetFeaturesAuggRotated.csv')

features=featureExtract(modelX, df2AugR['path'], 'x')

features['diag']=df2AugR['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/XceptionFeaturesAuggRotated.csv')
# Out:
# ...
# 1/1 [==============================] - 1s 612ms/step
# ...
# ...
# 1/1 [==============================] - 0s 364ms/step

# %%
#Estrazione feature secondo dataset con traslazione

features=featureExtract(modelE, df2AugT['path'], 'e')

features['diag']=df2AugT['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/EfficientNetFeaturesAuggTranslated.csv')

features=featureExtract(modelX, df2AugT['path'], 'x')

features['diag']=df2AugT['diag'] #aggiungiamo la colonna diag per la classificazione

features.to_csv('/content/drive/MyDrive/DeepLearning/Features/XceptionFeaturesAuggTranslated.csv')
# Out:
# ...
# 1/1 [==============================] - 0s 362ms/step
